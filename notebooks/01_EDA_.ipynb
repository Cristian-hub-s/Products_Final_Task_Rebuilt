# %% [markdown]
# # 01 - Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/products.csv')
df.columns = df.columns.str.strip()
df.head()

# %%
print(df.shape)
print(df.info())

# %%
df.isnull().sum()

# %%
df['Category Label'].value_counts().head(20).plot(kind='bar', figsize=(12,5))
plt.show()
