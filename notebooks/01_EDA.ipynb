# %% [markdown]
# # 01 - EDA

# %% [markdown]
# Load dataset and inspect shape.

# %% [markdown]
# Check missing values.

# %% [markdown]
# Analyze category distribution.

# %% [markdown]
# Visualize top categories.

# %% [markdown]
# Investigate title lengths and product examples.

# %% [markdown]
# Document findings and data quality issues.
