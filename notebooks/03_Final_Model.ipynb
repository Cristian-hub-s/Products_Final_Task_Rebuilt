# %% [markdown]
# # 03 - Final Model

# %% [markdown]
# Train final LGBMClassifier.

# %% [markdown]
# Generate classification report.

# %% [markdown]
# Generate confusion matrix.

# %% [markdown]
# Test manual examples.

# %% [markdown]
# Save product_classifier.pkl.
